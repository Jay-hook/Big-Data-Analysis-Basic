# %%
# 웹서버와 통신을 하는 라이브러리 
# !pip install requests

# %%
import requests

# %%
# localhost:5000/corona 요청
url = "http://127.0.0.1:5000/corona"

response = requests.get(url)

response
# Out:
# <Response [400]>

# %%
# 서버가 보내준 데이터를 bytes 형태로 출력
response.content
# Out:
# b'[{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-08 09:09:05.982","deathCnt":24305,"decideCnt":18188200,"seq":904,"stateDt":20220608,"stateTime":"00:00","updateDt":NaN},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-07 09:09:00.897","deathCnt":24299,"decideCnt":18174842,"seq":903,"stateDt":20220607,"stateTime":"00:00","updateDt":"2022-06-08 09:10:36.846"},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-06 09:00:06.734","deathCnt":24279,"decideCnt":18168670,"seq":902,"stateDt":20220606,"stateTime":"00:00","updateDt":"2022-06-08 09:10:50.441"},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-05 08:53:19.426","deathCnt":24258,"decideCnt":18163648,"seq":901,"stateDt":20220605,"stateTime":"00:00","updateDt":"2022-06-08 09:11:04.758"},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-04 08:56:49.219","deathCnt":24238,"decideCnt":18153814,"seq":900,"stateDt":20220604,"stateTime":"00:00","updateDt":"2022-06-08 09:11:26.303"},{"accDefRate":NaN,"accExamCnt":N
# ...

# %%
# 서버가 보내준 데이터를 문자열로 출력
response.text
# Out:
# '[{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-08 09:09:05.982","deathCnt":24305,"decideCnt":18188200,"seq":904,"stateDt":20220608,"stateTime":"00:00","updateDt":NaN},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-07 09:09:00.897","deathCnt":24299,"decideCnt":18174842,"seq":903,"stateDt":20220607,"stateTime":"00:00","updateDt":"2022-06-08 09:10:36.846"},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-06 09:00:06.734","deathCnt":24279,"decideCnt":18168670,"seq":902,"stateDt":20220606,"stateTime":"00:00","updateDt":"2022-06-08 09:10:50.441"},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-05 08:53:19.426","deathCnt":24258,"decideCnt":18163648,"seq":901,"stateDt":20220605,"stateTime":"00:00","updateDt":"2022-06-08 09:11:04.758"},{"accDefRate":NaN,"accExamCnt":NaN,"createDt":"2022-06-04 08:56:49.219","deathCnt":24238,"decideCnt":18153814,"seq":900,"stateDt":20220604,"stateTime":"00:00","updateDt":"2022-06-08 09:11:26.303"},{"accDefRate":NaN,"accExamCnt":Na
# ...

# %%
import pandas as pd

# %%
import json

# %%
# 서버가 보내준 데이터를 dict의 형태로 출력
res = json.loads(response.text)

# %%
res['data']
# Out:
# [['2022-06-08 09:09:05.982',
#   24305,
#   18188200,
#   904,
#   20220608,
#   '00:00',
#   nan,
#   nan,
#   nan],
#  ['2022-06-07 09:09:00.897',
#   24299,
#   18174842,
#   903,
#   20220607,
#   '00:00',
#   '2022-06-08 09:10:36.846',
#   nan,
#   nan],
#  ['2022-06-06 09:00:06.734',
#   24279,
#   18168670,
#   902,
#   20220606,
#   '00:00',
#   '2022-06-08 09:10:50.441',
#   nan,
#   nan],
#  ['2022-06-05 08:53:19.426',
#   24258,
#   18163648,
#   901,
#   20220605,
#   '00:00',
#   '2022-06-08 09:11:04.758',
#   nan,
#   nan],
#  ['2022-06-04 08:56:49.219',
#   24238,
#   18153814,
#   900,
#   20220604,
#   '00:00',
#   '2022-06-08 09:11:26.303',
#   nan,
#   nan],
#  ['2022-06-03 09:08:18.729',
#   24229,
#   18141775,
#   899,
#   20220603,
#   '00:00',
#   '2022-06-08 09:11:38.938',
#   nan,
#   nan],
#  ['2022-06-02 08:58:19.746',
#   24212,
#   18129236,
#   898,
#   20220602,
#   '00:00',
#   '2022-06-08 09:11:51.985',
#   nan,
#   nan],
# ...

# %%
pd.DataFrame(res['data'], index=res['index'], columns=res['columns'])
# Out:
#                     createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0    2022-06-08 09:09:05.982     24305   18188200  904  20220608     00:00
# 1    2022-06-07 09:09:00.897     24299   18174842  903  20220607     00:00
# 2    2022-06-06 09:00:06.734     24279   18168670  902  20220606     00:00
# 3    2022-06-05 08:53:19.426     24258   18163648  901  20220605     00:00
# 4    2022-06-04 08:56:49.219     24238   18153814  900  20220604     00:00
# ..                       ...       ...        ...  ...       ...       ...
# 815  2020-03-14 00:00:00.000        72       8086   55  20200314     00:00
# 816  2020-03-13 00:00:00.000        67       7979   54  20200313     00:00
# 817  2020-03-12 00:00:00.000        66       7869   53  20200312     00:00
# 818  2020-03-11 00:00:00.000        60       7755   52  20200311     00:00
# 819  2020-03-10 00:00:00.000        54       7513   51  20200310     00:00
#
#                     updateDt  accExamCnt  accDefRate
# ...

# %%
url = 'http://127.0.0.1:5000/corona'

params = {
    'serviceKey' : 'ubion2'
}

response = requests.get(url, params = params)

response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# 'serviceKey Error'
